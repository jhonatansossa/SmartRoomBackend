# %%
from flask import Flask
from db_setup import db
app = Flask(__name__)
app.config['SQLALCHEMY_DATABASE_URI'] = 'mysql+pymysql://root:$TiN7pR0y3Ct@localhost/openhab2'
db.init_app(app)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[58], line 2
#       1 from flask import Flask
# ----> 2 from db_setup import db
#       3 app = Flask(__name__)
#       4 app.config['SQLALCHEMY_DATABASE_URI'] = 'mysql+pymysql://root:$TiN7pR0y3Ct@localhost/openhab2'
#
# ModuleNotFoundError: No module named 'db_setup'

# %%
import sys
sys.path.append('/home/usrdsd/API')

# %%
from flask import Blueprint, jsonify, request, make_response
from src.constants.http_status_codes import HTTP_200_OK, HTTP_400_BAD_REQUEST, HTTP_404_NOT_FOUND
from src.database import Relations, Names, db, create_item_models
from src.database import User
from sqlalchemy import func
from flasgger import swag_from
import requests 
import os
from flask_jwt_extended import jwt_required

# %%
itemname = 'ZWaveNode004HS2SKZSmartMeteringPlug_Switch'
url = f"https://home.myopenhab.org/rest/items/{itemname}/state"
username = "jsossa2@gmail.com"
password = "458956c07"

response  = requests.get(url, auth=(username, password))
print(response.status_code)
print(response.content)
# Out:
# 200
# b'ON'

# %%
itemname = 'ZWaveNode004HS2SKZSmartMeteringPlug_Switch'
url = f"https://home.myopenhab.org/rest/items/{itemname}/state"
username = "jsossa2@gmail.com"
password = "458956c07"
headers = {'Content-type': 'text/plain'}
data = "10"

response  = requests.put(url, data=data, headers=headers, auth=(username, password))
print(response.status_code)
print(response.content)
# Out:
# 400
# b'{"error":{"message":"State could not be parsed: 10","http-code":400}}'

# %%
response.json()
# Out:
# [{'link': 'https://myopenhab.org/rest/items/30_APARENT_IMPORT_KVAH',
#   'state': '1161.3',
#   'stateDescription': {'pattern': '%.0f', 'readOnly': False, 'options': []},
#   'editable': True,
#   'type': 'Number',
#   'name': '30_APARENT_IMPORT_KVAH',
#   'label': '30_APARENT_IMPORT_KVAH',
#   'category': '',
#   'tags': ['Point'],
#   'groupNames': []},
#  {'link': 'https://myopenhab.org/rest/items/28ACTIVENETL1_ValueasNumber',
#   'state': '0.0',
#   'stateDescription': {'pattern': '%.0f', 'readOnly': False, 'options': []},
#   'editable': True,
#   'type': 'Number',
#   'name': '28ACTIVENETL1_ValueasNumber',
#   'label': '28_ACTIVE_NET_L1',
#   'category': '',
#   'tags': ['Point'],
#   'groupNames': []},
#  {'link': 'https://myopenhab.org/rest/items/25_ACTIVE_EXPORT_KWH',
#   'state': '72.89',
#   'stateDescription': {'pattern': '%.0f', 'readOnly': False, 'options': []},
#   'editable': True,
#   'type': 'Number',
#   'name': '25_ACTIVE_EXPORT_KWH',
# ...

# %%
from flask import Blueprint, jsonify, request, make_response

# %%
x = requests.get('http://openhab:8080/rest/items/ZWaveSerialController_OOFBytsReceived?recursive=false')
x.json()
# Out:
# {'error': {'message': 'Item ZWaveSerialController_OOFBytsReceived does not exist!',
#   'http-code': 404}}

# %%
ID=30
measurement="active_import_energy"
start_time="2021-12-01 02:57:43.113"
end_time="2021-12-01 02:59:00.022"

if start_time >= end_time:
    response = make_response(jsonify({
        'error': 'The start time is greater than end time'
    }))
    response.status_code=HTTP_400_BAD_REQUEST
else: 
    names=Names.query.filter_by(ID=ID).first()
    if names:
        if measurement in energy_types:
            relations = Relations.query.filter_by(ID=ID).first()
            col_name = energy_types[measurement]

            id = relations.serialize[col_name]

            if id:
                item = create_item_models('item00'+str(id))
                query = item.query.filter(item.TIME >= start_time, item.TIME <= end_time).all()
                response = make_response(jsonify(lastMeasurements=[i.serialize for i in query]))
                response.status_code=HTTP_200_OK
            else:
                response = make_response(jsonify({'error': 'The measurement was not found'}))
                response.status_code=HTTP_404_NOT_FOUND
        else:
            response = make_response(jsonify({'error': 'That measurement does not exist'}))
            response.status_code=HTTP_404_NOT_FOUND
    else: 
        response = make_response(jsonify({'error': 'Wrong id'}))
        response.status_code = HTTP_400_BAD_REQUEST
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[57], line 12
#      10     response.status_code=HTTP_400_BAD_REQUEST
#      11 else:
# ---> 12     names=Names.query.filter_by(ID=ID).first()
#      13     if names:
#      14         if measurement in energy_types:
#
# File ~/miniconda3/envs/back_dev/lib/python3.8/site-packages/flask_sqlalchemy/model.py:31, in _QueryProperty.__get__(self, obj, cls)
#      29 def __get__(self, obj: Model | None, cls: t.Type[Model]) -> Query:
#      30     return cls.query_class(
# ---> 31         cls, session=cls.__fsa__.session()  # type: ignore[arg-type]
#      32     )
#
# File ~/miniconda3/envs/back_dev/lib/python3.8/site-packages/sqlalchemy/orm/scoping.py:47, in ScopedSessionMixin.__call__(self, **kw)
#      45         self.registry.set(sess)
#      46 else:
# ---> 47     sess = self.registry()
# ...
