# %%
import requests

# %%
x = requests.get('http://openhab:8080/rest/items?recursive=false')

# %%
x.json()
# Out:
# [{'link': 'http://openhab:8080/rest/items/ZWaveSerialController_OOFBytesReceived',
#   'state': '0.0',
#   'editable': True,
#   'type': 'Number',
#   'name': 'ZWaveSerialController_OOFBytesReceived',
#   'label': 'OOF Bytes Received',
#   'category': '',
#   'tags': ['Point'],
#   'groupNames': []},
#  {'link': 'http://openhab:8080/rest/items/ZWaveNode006MotionSensor_BatteryLevel',
#   'state': '100.0',
#   'stateDescription': {'minimum': 0,
#    'maximum': 100,
#    'step': 1,
#    'pattern': '%.0f %%',
#    'readOnly': True,
#    'options': []},
#   'editable': True,
#   'type': 'Number',
#   'name': 'ZWaveNode006MotionSensor_BatteryLevel',
#   'label': '06-Battery Level',
#   'category': 'Battery',
#   'tags': ['Point'],
#   'groupNames': []},
#  {'link': 'http://openhab:8080/rest/items/ZWaveNode006MotionSensor_Alarmgeneral',
#   'state': 'OFF',
#   'stateDescription': {'readOnly': True,
#    'options': [{'value': 'OFF', 'label': 'OK'},
#     {'value': 'ON', 'label': 'Alarm'}]},
# ...

# %%
from flask import Blueprint, jsonify, request, make_response

# %%
x = request.get('http://openhab:8080/rest/items?recursive=false')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 x = request.get('http://openhab:8080/rest/items?recursive=false')
#
# File ~/miniconda3/envs/back_dev/lib/python3.8/site-packages/werkzeug/local.py:316, in _ProxyLookup.__get__(self, instance, owner)
#     313     return self
#     315 try:
# --> 316     obj = instance._get_current_object()  # type: ignore[misc]
#     317 except RuntimeError:
#     318     if self.fallback is None:
#
# File ~/miniconda3/envs/back_dev/lib/python3.8/site-packages/werkzeug/local.py:513, in LocalProxy.__init__.<locals>._get_current_object()
#     511     obj = local.get()  # type: ignore[union-attr]
#     512 except LookupError:
# --> 513     raise RuntimeError(unbound_message) from None
#     515 return get_name(obj)
#
# RuntimeError: Working outside of request context.
#
# ...
